# %%
import pandas as pd
import re

pd.options.display.float_format = '{:.0f}'.format

# %% [markdown]
# ### 1. 꼭 read_csv 21상반기, 19하반기와 같이 맞추어 주세요!!! 또한 지역(전라북도, 남도) 맞추기!!!!!

# %%
df = pd.read_csv('강원도_계약종별_전력사용량_월별_19하반기.csv', encoding='cp949')

df
#exchng=  pd.read_csv('지역별_전력거래량_20220803093050.csv' , encoding='cp949')
# Out:
#       계약종별 전력사용량 월별( 20220804 현재 ) Unnamed: 1     Unnamed: 2 Unnamed: 3  \
# 0    시도 : 강원도, 시군구 : 전체(시 / 군 / 구)        NaN            NaN        NaN
# 1      기간 : 2019년 07 월 ~ 2019년 12월        NaN            NaN        NaN
# 2                               년월         시구            시군구       계약구분
# 3                           201907        강원도  전체(시 / 군 / 구)        주택용
# 4                           201907        강원도  전체(시 / 군 / 구)        일반용
# ..                             ...        ...            ...        ...
# 907                         201912        강원도            횡성군        산업용
# 908                         201912        강원도            횡성군        심 야
# 909                         201912        강원도            횡성군        일반용
# 910                         201912        강원도            횡성군        주택용
# 911                         201912        강원도            횡성군         합계
#
#     Unnamed: 4    Unnamed: 5       Unnamed: 6     Unnamed: 7
# 0          NaN           NaN              NaN            NaN
# 1          NaN           NaN              NaN            NaN
# 2      고객호수(호)      사용량(kWh)          전기요금(원)  평균판매단가(원/kWh)
# 3     600,817   166,026,328   15,711,090,342           94.6
# 4     146,145   368,475,620   55,310,089,495          150.1
# ..         ...           ...              ...            ...
# 907       740    18,582,657    2,515,168,627          135.4
# 908     6,254    14,157,755    1,057,459,102           74.7
# 909     5,173    13,326,720    1,755,531,950          131.7
# 910    25,519     5,453,432      612,156,235          112.3
# 911    57,241    59,732,405    6,453,741,076            108
#
# [912 rows x 8 columns]

# %%
df = df.drop([0,1 , 46] , axis = 0)
#0,1 , 10은 지우는게 맞다
df
# Out:
#     계약종별 전력사용량 월별( 20220804 현재 ) Unnamed: 1     Unnamed: 2 Unnamed: 3  \
# 2                             년월         시구            시군구       계약구분
# 3                         201907        강원도  전체(시 / 군 / 구)        주택용
# 4                         201907        강원도  전체(시 / 군 / 구)        일반용
# 5                         201907        강원도  전체(시 / 군 / 구)        교육용
# 6                         201907        강원도  전체(시 / 군 / 구)        산업용
# ..                           ...        ...            ...        ...
# 907                       201912        강원도            횡성군        산업용
# 908                       201912        강원도            횡성군        심 야
# 909                       201912        강원도            횡성군        일반용
# 910                       201912        강원도            횡성군        주택용
# 911                       201912        강원도            횡성군         합계
#
#     Unnamed: 4    Unnamed: 5       Unnamed: 6     Unnamed: 7
# 2      고객호수(호)      사용량(kWh)          전기요금(원)  평균판매단가(원/kWh)
# 3     600,817   166,026,328   15,711,090,342           94.6
# 4     146,145   368,475,620   55,310,089,495          150.1
# 5       1,063    22,369,103    2,885,917,110          129.0
# 6      13,738   558,898,776   65,289,760,164          116.8
# ..         ...           ...              ...            ...
# 907       740    18,582,657    2,515,168,627          135.4
# 908     6,254    14,157,755    1,057,459,102           74.7
# 909     5,173    13,326,720    1,755,531,950          131.7
# 910    25,519     5,453,432      612,156,235          112.3
# 911    57,241    59,732,405    6,453,741,076            108
#
# [909 rows x 8 columns]

# %%
a= df.loc[2].tolist()
a
df = df.drop([2] , axis = 0)

# %%
df.columns = a
df
# Out:
#          년월   시구            시군구 계약구분   고객호수(호)      사용량(kWh)          전기요금(원)  \
# 3    201907  강원도  전체(시 / 군 / 구)  주택용  600,817   166,026,328   15,711,090,342
# 4    201907  강원도  전체(시 / 군 / 구)  일반용  146,145   368,475,620   55,310,089,495
# 5    201907  강원도  전체(시 / 군 / 구)  교육용    1,063    22,369,103    2,885,917,110
# 6    201907  강원도  전체(시 / 군 / 구)  산업용   13,738   558,898,776   65,289,760,164
# 7    201907  강원도  전체(시 / 군 / 구)  농사용  107,403    56,494,072    2,818,038,416
# ..      ...  ...            ...  ...       ...           ...              ...
# 907  201912  강원도            횡성군  산업용      740    18,582,657    2,515,168,627
# 908  201912  강원도            횡성군  심 야    6,254    14,157,755    1,057,459,102
# 909  201912  강원도            횡성군  일반용    5,173    13,326,720    1,755,531,950
# 910  201912  강원도            횡성군  주택용   25,519     5,453,432      612,156,235
# 911  201912  강원도            횡성군   합계   57,241    59,732,405    6,453,741,076
#
#     평균판매단가(원/kWh)
# 3           94.6
# 4          150.1
# 5          129.0
# 6          116.8
# 7           49.9
# ..            ...
# 907        135.4
# 908         74.7
# 909        131.7
# 910        112.3
# 911          108
#
# [908 rows x 8 columns]

# %%
df_2 = df.loc[:45]
df_2
# Out:
#         년월   시구            시군구 계약구분    고객호수(호)       사용량(kWh)  \
# 3   201907  강원도  전체(시 / 군 / 구)  주택용   600,817    166,026,328
# 4   201907  강원도  전체(시 / 군 / 구)  일반용   146,145    368,475,620
# 5   201907  강원도  전체(시 / 군 / 구)  교육용     1,063     22,369,103
# 6   201907  강원도  전체(시 / 군 / 구)  산업용    13,738    558,898,776
# 7   201907  강원도  전체(시 / 군 / 구)  농사용   107,403     56,494,072
# 8   201907  강원도  전체(시 / 군 / 구)  가로등   118,257     15,876,320
# 9   201907  강원도  전체(시 / 군 / 구)  심 야    89,815     42,084,649
# 10  201908  강원도  전체(시 / 군 / 구)  주택용   602,262    216,909,450
# 11  201908  강원도  전체(시 / 군 / 구)  일반용   146,601    444,572,132
# 12  201908  강원도  전체(시 / 군 / 구)  교육용     1,062     22,328,866
# 13  201908  강원도  전체(시 / 군 / 구)  산업용    13,780    552,252,636
# 14  201908  강원도  전체(시 / 군 / 구)  농사용   108,155     69,905,226
# 15  201908  강원도  전체(시 / 군 / 구)  가로등   118,625     16,246,972
# 16  201908  강원도  전체(시 / 군 / 구)  심 야    89,647     37,197,024
# 17  201909  강원도  전체(시 / 군 / 구)  주택용   603,681    192,177,261
# 18  201909  강원도  전체(시 / 군 / 구)  일반용   146,912    383,391,891
# 19  201909  강원도  전체(시 / 군 / 구)  교육용     1,062     24,534,665
# 20  201909  강원도  전체(시 / 군 / 구)  산업용    13,798    530,931,746
# 21  201909  강원도  전체(시 / 군 / 구)  농사용   108,842     77,607,773
# 22  201909  강원도  전체(시 / 군 / 구)  가로등   119,221     16,572,005
# 23  201909  강원도  전체(시 / 군 / 구)  심 야    89,515     36,670,296
# 24  201910  강원도  전체(시 / 군 / 구)  주택용   605,287    168,376,105
# 25  201910  강원도  전체(시 / 군 / 구)  일반용   147,201    330,293,800
# 26  201910  강원도  전체(시 / 군 / 구)  교육용     1,060     20,819,226
# 27  201910  강원도  전체(시 / 군 / 구)  산업용    13,836    574,163,583
# 28  201910  강원도  전체(시 / 군 / 구)  농사용   109,226     64,234,855
# 29  201910  강원도  전체(시 / 군 / 구)  가로등   119,555     16,841,160
# 30  201910  강원도  전체(시 / 군 / 구)  심 야    89,416     59,186,830
# 31  201911  강원도  전체(시 / 군 / 구)  주택용   606,155    178,138,087
# 32  201911  강원도  전체(시 / 군 / 구)  일반용   147,799    357,229,302
# 33  201911  강원도  전체(시 / 군 / 구)  교육용     1,060     25,524,181
# 34  201911  강원도  전체(시 / 군 / 구)  산업용    13,906    572,513,906
# 35  201911  강원도  전체(시 / 군 / 구)  농사용   131,831     77,259,444
# 36  201911  강원도  전체(시 / 군 / 구)  가로등   119,934     17,431,055
# 37  201911  강원도  전체(시 / 군 / 구)  심 야    89,320    117,890,073
# 38  201912  강원도  전체(시 / 군 / 구)  주택용   606,879    187,295,741
# 39  201912  강원도  전체(시 / 군 / 구)  일반용   148,373    433,919,971
# 40  201912  강원도  전체(시 / 군 / 구)  교육용     1,063     38,093,685
# 41  201912  강원도  전체(시 / 군 / 구)  산업용    13,925    584,331,192
# 42  201912  강원도  전체(시 / 군 / 구)  농사용   109,519     56,439,036
# 43  201912  강원도  전체(시 / 군 / 구)  가로등   120,302     17,249,151
# 44  201912  강원도  전체(시 / 군 / 구)  심 야    89,200    190,036,832
# 45      합계   합계             합계   합계  6,525,248  7,938,790,026
#
#             전기요금(원) 평균판매단가(원/kWh)
# 3   15,711,090,342          94.6
# 4   55,310,089,495         150.1
# 5    2,885,917,110         129.0
# 6   65,289,760,164         116.8
# 7    2,818,038,416          49.9
# 8    1,905,693,847         120.0
# 9    2,370,670,840          56.3
# 10  21,701,025,364         100.0
# 11  63,155,556,856         142.1
# 12   2,913,065,657         130.5
# 13  63,004,251,054         114.1
# 14   3,415,505,525          48.9
# 15   1,901,158,392         117.0
# 16   2,140,605,573          57.5
# 17  18,891,109,759          98.3
# 18  49,613,485,993         129.4
# 19   2,791,208,738         113.8
# 20  50,136,355,575          94.4
# 21   3,738,175,883          48.2
# 22   1,908,532,575         115.2
# 23   2,074,227,091          56.6
# 24  16,669,821,401          99.0
# 25  39,130,702,474         118.5
# 26   2,064,349,556          99.2
# 27  51,546,141,802          89.8
# 28   3,215,520,023          50.1
# 29   1,888,783,324         112.2
# 30   3,263,449,278          55.1
# 31  18,362,280,167         103.1
# 32  46,623,283,367         130.5
# 33   2,776,697,684         108.8
# 34  63,441,861,239         110.8
# 35   3,445,420,337          44.6
# 36   1,923,333,810         110.3
# 37   7,441,586,701          63.1
# 38  19,911,744,545         106.3
# 39  57,903,844,996         133.4
# 40   3,803,806,179          99.9
# 41  64,532,598,791         110.4
# 42   2,895,999,361          51.3
# 43   1,877,123,784         108.8
# 44  14,233,085,322          74.9
# 45  860,626,958,390         108.4

# %%
GyeonGi  = df_2.loc[(df_2['계약구분'] == '일반용')]
#SEOUL = df_3.loc[(df_3['계약구분'] =='일반용')]
GyeonGi.drop(['시군구' , '전기요금(원)' , '평균판매단가(원/kWh)'] , axis = 1 , inplace = True)
GyeonGi
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_15048\730399353.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   GyeonGi.drop(['시군구' , '전기요금(원)' , '평균판매단가(원/kWh)'] , axis = 1 , inplace = True)
#         년월   시구 계약구분   고객호수(호)      사용량(kWh)
# 4   201907  강원도  일반용  146,145   368,475,620
# 11  201908  강원도  일반용  146,601   444,572,132
# 18  201909  강원도  일반용  146,912   383,391,891
# 25  201910  강원도  일반용  147,201   330,293,800
# 32  201911  강원도  일반용  147,799   357,229,302
# 39  201912  강원도  일반용  148,373   433,919,971

# %%
#SEOUL1.to_csv("서울특별시_계약종별_전국_전력사용량_2022.csv" , mode = 'w' , encoding= 'cp949')

# %%
#df_2.to_csv("서울특별시_계약종별_전국_전력사용량.csv" , mode = 'w' , encoding= 'cp949')

# %%
df_3 = df.loc[48:]
df_3 = df_3.loc[(df_3['계약구분'] == '일반용')]
df_3 = df_3.sort_values(by=['시군구' , '년월'])
df_3.drop(['전기요금(원)',   '평균판매단가(원/kWh)'] , axis = 1 , inplace = True)
df_3
# Out:
#          년월   시구  시군구 계약구분  고객호수(호)     사용량(kWh)
# 53   201907  강원도  강릉시  일반용  20,226   46,929,489
# 197  201908  강원도  강릉시  일반용  20,298   58,946,725
# 341  201909  강원도  강릉시  일반용  20,343   51,028,752
# 485  201910  강원도  강릉시  일반용  20,389   41,918,030
# 629  201911  강원도  강릉시  일반용  20,458   43,272,598
# ..      ...  ...  ...  ...      ...          ...
# 333  201908  강원도  횡성군  일반용   5,104   10,702,346
# 477  201909  강원도  횡성군  일반용   5,115    9,326,367
# 621  201910  강원도  횡성군  일반용   5,135    8,396,458
# 765  201911  강원도  횡성군  일반용   5,140    9,879,667
# 909  201912  강원도  횡성군  일반용   5,173   13,326,720
#
# [108 rows x 6 columns]

# %%
a = df_3.loc[: , "시구"]
b = a[:1].tolist()
for i in b:
    City = i
City
# Out:
# '강원도'

# %%
SIGUNGU = list(set(df_3.loc[: , '시군구'].tolist()))
SIGUNGU.sort()
SIGUNGU
# Out:
# ['강릉시',
#  '고성군',
#  '동해시',
#  '삼척시',
#  '속초시',
#  '양구군',
#  '양양군',
#  '영월군',
#  '원주시',
#  '인제군',
#  '정선군',
#  '철원군',
#  '춘천시',
#  '태백시',
#  '평창군',
#  '홍천군',
#  '화천군',
#  '횡성군']

# %%
df_4 = df.loc[48:]
df_4 = df_4.loc[(df_4['계약구분'] == '합계')]
df_4 = df_4.sort_values(by=['시군구' , '년월'])
df_4.drop(['전기요금(원)',   '평균판매단가(원/kWh)'] , axis = 1 , inplace = True)
df_4
# Out:
#          년월   시구  시군구 계약구분   고객호수(호)      사용량(kWh)
# 55   201907  강원도  강릉시   합계  136,486   146,514,112
# 199  201908  강원도  강릉시   합계  136,934   172,162,506
# 343  201909  강원도  강릉시   합계  137,110   149,502,874
# 487  201910  강원도  강릉시   합계  137,320   147,506,328
# 631  201911  강원도  강릉시   합계  137,770   163,873,523
# ..      ...  ...  ...  ...       ...           ...
# 335  201908  강원도  횡성군   합계   56,664    47,122,276
# 479  201909  강원도  횡성군   합계   56,823    43,878,954
# 623  201910  강원도  횡성군   합계   56,967    42,678,222
# 767  201911  강원도  횡성군   합계   59,125    50,866,430
# 911  201912  강원도  횡성군   합계   57,241    59,732,405
#
# [108 rows x 6 columns]

# %%
sum2 , sum3 =[] , []
for k in SIGUNGU:
    GyeonGiHap = pd.DataFrame([] , columns = a)
    HOSU = pd.DataFrame([], columns = a)
    GyeonGiHap['사용량']= df_4['사용량(kWh)'].loc[(df_4['시군구'] == '{}'.format(k))]
    HOSU['고객호수']= df_4['고객호수(호)'].loc[(df_4['시군구'] == '{}'.format(k))]
    #경기합 데이터프레임의 사용량 열에 기군구가 가평군인 사용량 데이터만 뽑아내기
    # GyeonGiHap = GyeonGiHap['사용량']

    b = GyeonGiHap['사용량'].tolist()
    c = HOSU['고객호수'].tolist()


    #각지역별 사용량 리스트화
    int_list  , int_list2=[] , []
    for i in b:
        i = re.sub("," , "" , i)
        #콤마 없애기
        int_list.append(int(i))
        #int_list에 각지역별 사용량 int로 저장
    print(int_list)
    sum=0
    for i in c:
        i = re.sub("," , "" , i)
        int_list2.append(int(i))

    for j in int_list:

        sum+= j
    sum2.append(sum)
    sum = 0
    for j in int_list2: #고객호수 추출하여 더하기

        sum+= j
    sum3.append(sum//36) #6개월 치로 나눠야하나?!




print("{} 지역별 합계 : ".format(City) , sum2)
print("{} 고객호수 평균: ".format(City) , sum3)
# Out:
# [146514112, 172162506, 149502874, 147506328, 163873523, 175343812]
# [22379845, 26911942, 24143303, 22460927, 24963859, 28468462]
# [170366461, 184563889, 183481768, 185502029, 164369553, 174649262]
# [126368465, 122208518, 116893806, 123207791, 134538720, 139801409]
# [39701888, 49409128, 43084510, 37979687, 40283507, 45583580]
# [14241557, 16339768, 15642254, 14637863, 19641536, 21363655]
# [21335288, 26306670, 23833643, 21749666, 24036061, 27468885]
# [89161299, 86640377, 84739739, 92374616, 97492197, 103845611]
# [186691313, 209057609, 193977946, 179338565, 198308413, 227054470]
# [22237019, 25550693, 23625176, 23204500, 28184394, 33514470]
# [47770942, 50410306, 47124894, 50748720, 54308920, 64895452]
# [33474080, 37163749, 34074826, 32111040, 46145120, 47834137]
# [136729941, 157990171, 142396118, 127815928, 139053603, 163734041]
# [21910900, 23382933, 22562952, 23030697, 25833436, 30178231]
# [40183580, 44951787, 40824549, 43068428, 53423539, 67481856]
# [52208803, 59606614, 53688765, 49746851, 60157071, 71395839]
# [16645906, 19633370, 18409560, 16753701, 20506166, 25020031]
# [42303469, 47122276, 43878954, 42678222, 50866430, 59732405]
# 강원도 지역별 합계 :  [954903155, 149328338, 1062932962, 763018709, 256042300, 101866633, 144730213, 554253839, 1194428316, 156316252, 315259234, 230802952, 867719802, 146899149, 289933739, 346803943, 116968734, 286581756]
# 강원도 고객호수 평균:  [22869, 4944, 8279, 9430, 6826, 4057, 5282, 6955, 27479, 6054, 6705, 7401, 24648, 4666, 9091, 12610, 4415, 9535]

# %% [markdown]
# ### 2. 날짜 체크!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

# %%
Hap = df_4.copy()
Hap.reset_index(drop=True , inplace = True)
for i in range(len(SIGUNGU)):
    Hap = Hap.append({'년월' :'201907-201912'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
Hap
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_15048\51496957.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'201907-201912'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_15048\51496957.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'201907-201912'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_15048\51496957.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'201907-201912'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_15048\51496957.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'201907-201912'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_15048\51496957.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'201907-201912'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_15048\51496957.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'201907-201912'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_15048\51496957.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'201907-201912'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_15048\51496957.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'201907-201912'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_15048\51496957.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'201907-201912'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_15048\51496957.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'201907-201912'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_15048\51496957.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'201907-201912'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_15048\51496957.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'201907-201912'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_15048\51496957.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'201907-201912'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_15048\51496957.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'201907-201912'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_15048\51496957.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'201907-201912'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_15048\51496957.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'201907-201912'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_15048\51496957.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'201907-201912'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_15048\51496957.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Hap = Hap.append({'년월' :'201907-201912'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '합계' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
#                 년월   시구  시군구 계약구분   고객호수(호)      사용량(kWh)
# 0           201907  강원도  강릉시   합계  136,486   146,514,112
# 1           201908  강원도  강릉시   합계  136,934   172,162,506
# 2           201909  강원도  강릉시   합계  137,110   149,502,874
# 3           201910  강원도  강릉시   합계  137,320   147,506,328
# 4           201911  강원도  강릉시   합계  137,770   163,873,523
# ..             ...  ...  ...  ...       ...           ...
# 121  201907-201912  강원도  태백시   합계      4666     146899149
# 122  201907-201912  강원도  평창군   합계      9091     289933739
# 123  201907-201912  강원도  홍천군   합계     12610     346803943
# 124  201907-201912  강원도  화천군   합계      4415     116968734
# 125  201907-201912  강원도  횡성군   합계      9535     286581756
#
# [126 rows x 6 columns]

# %% [markdown]
# ### 3. 날짜 변경!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

# %%
Hap = Hap.loc[Hap['년월'] == '201907-201912']
Hap
# Out:
#                 년월   시구  시군구 계약구분 고객호수(호)    사용량(kWh)
# 108  201907-201912  강원도  강릉시   합계   22869   954903155
# 109  201907-201912  강원도  고성군   합계    4944   149328338
# 110  201907-201912  강원도  동해시   합계    8279  1062932962
# 111  201907-201912  강원도  삼척시   합계    9430   763018709
# 112  201907-201912  강원도  속초시   합계    6826   256042300
# 113  201907-201912  강원도  양구군   합계    4057   101866633
# 114  201907-201912  강원도  양양군   합계    5282   144730213
# 115  201907-201912  강원도  영월군   합계    6955   554253839
# 116  201907-201912  강원도  원주시   합계   27479  1194428316
# 117  201907-201912  강원도  인제군   합계    6054   156316252
# 118  201907-201912  강원도  정선군   합계    6705   315259234
# 119  201907-201912  강원도  철원군   합계    7401   230802952
# 120  201907-201912  강원도  춘천시   합계   24648   867719802
# 121  201907-201912  강원도  태백시   합계    4666   146899149
# 122  201907-201912  강원도  평창군   합계    9091   289933739
# 123  201907-201912  강원도  홍천군   합계   12610   346803943
# 124  201907-201912  강원도  화천군   합계    4415   116968734
# 125  201907-201912  강원도  횡성군   합계    9535   286581756

# %%
# SIGUNGU = SIGUNGU[:1]
# SIGUNGU
#for i in SIGUNGU:
#print('{}'.format(i))
# df_3 = df_3.loc[(df_3['시군구'] == '가평군')]
#
# df_3

# %%
a = (df_3.columns).tolist()

a
# Out:
# ['년월', '시구', '시군구', '계약구분', '고객호수(호)', '사용량(kWh)']

# %%
df_3
# Out:
#          년월   시구  시군구 계약구분  고객호수(호)     사용량(kWh)
# 53   201907  강원도  강릉시  일반용  20,226   46,929,489
# 197  201908  강원도  강릉시  일반용  20,298   58,946,725
# 341  201909  강원도  강릉시  일반용  20,343   51,028,752
# 485  201910  강원도  강릉시  일반용  20,389   41,918,030
# 629  201911  강원도  강릉시  일반용  20,458   43,272,598
# ..      ...  ...  ...  ...      ...          ...
# 333  201908  강원도  횡성군  일반용   5,104   10,702,346
# 477  201909  강원도  횡성군  일반용   5,115    9,326,367
# 621  201910  강원도  횡성군  일반용   5,135    8,396,458
# 765  201911  강원도  횡성군  일반용   5,140    9,879,667
# 909  201912  강원도  횡성군  일반용   5,173   13,326,720
#
# [108 rows x 6 columns]

# %%
# GyeonGiHap = pd.DataFrame([] , columns = a)
# GyeonGiHap['사용량']= df_3['사용량(kWh)'].loc[(df_3['시군구'] == '{가평군}')]
# GyeonGiHap

# %%
sum2 , sum3 =[] , []
for k in SIGUNGU:
    GyeonGiHap = pd.DataFrame([] , columns = a)
    HOSU = pd.DataFrame([], columns = a)
    GyeonGiHap['사용량']= df_3['사용량(kWh)'].loc[(df_3['시군구'] == '{}'.format(k))]
    HOSU['고객호수']= df_3['고객호수(호)'].loc[(df_3['시군구'] == '{}'.format(k))]
    #경기합 데이터프레임의 사용량 열에 기군구가 가평군인 사용량 데이터만 뽑아내기
    # GyeonGiHap = GyeonGiHap['사용량']

    b = GyeonGiHap['사용량'].tolist()
    c = HOSU['고객호수'].tolist()


    #각지역별 사용량 리스트화
    int_list  , int_list2=[] , []
    for i in b:
        i = re.sub("," , "" , i)
        #콤마 없애기
        int_list.append(int(i))
        #int_list에 각지역별 사용량 int로 저장
    print(int_list)
    sum=0
    for i in c:
        i = re.sub("," , "" , i)
        int_list2.append(int(i))

    for j in int_list:

        sum+= j
    sum2.append(sum)
    sum = 0
    for j in int_list2: #고객호수 추출하여 더하기

        sum+= j
    sum3.append(sum//6) #6개월 치로 나눠야하나?!




print("{} 지역별 일반용 합계 : ".format(City) , sum2)
print("{} 고객호수 평균: ".format(City) , sum3)
# GyeonGiHap['합계'] = sum
#
# GyeonGiHap
# Out:
# [46929489, 58946725, 51028752, 41918030, 43272598, 49782943]
# [11089923, 14285975, 11769455, 10189873, 10615437, 12545434]
# [16574362, 21125265, 18752700, 15851595, 16464020, 18730899]
# [13318317, 16671567, 14153202, 12079598, 12669423, 14392316]
# [22621528, 28942083, 24467534, 20531722, 20862842, 23538092]
# [6702488, 7849435, 7024703, 5964846, 6866083, 8197134]
# [10184669, 13424774, 11544737, 9536185, 10108490, 11791858]
# [6500720, 8071015, 7418865, 6172546, 6631143, 7864263]
# [65570369, 76960070, 68243800, 57325860, 60057444, 73548290]
# [11127021, 13487032, 11284461, 10200328, 11978205, 14311712]
# [16149265, 18975861, 15284690, 14447256, 17375747, 24189024]
# [11973658, 13998528, 11899117, 10429366, 12321925, 15202095]
# [66962417, 76947501, 68832266, 59973954, 61856544, 71424987]
# [6754796, 7868543, 7185350, 6625481, 7466142, 9567827]
# [16910635, 20182193, 15682116, 15712772, 20126966, 29020594]
# [21557178, 25615257, 20172312, 17150569, 19750466, 25120275]
# [8641268, 10517962, 9321464, 7787361, 8926160, 11365508]
# [8907517, 10702346, 9326367, 8396458, 9879667, 13326720]
# 강원도 지역별 일반용 합계 :  [291878537, 70496097, 107498841, 83284423, 140963801, 42604689, 66590713, 42658552, 401705833, 72388759, 106421843, 75824689, 405997669, 45468139, 117635276, 129366057, 56559723, 60539075]
# 강원도 고객호수 평균:  [20378, 4025, 7249, 6747, 8260, 2793, 4332, 4166, 25943, 4682, 5067, 4875, 21142, 4139, 6506, 8348, 3387, 5125]

# %%
# df_3 = df_3.loc[(df_3['시군구'] == '가평군')]
#
# df_3

# %%
# GyeonGiHap = df_3.copy()
# GyeonGiHap.reset_index(drop=True , inplace = True)
# GyeonGiHap.append({'년월' : '202107-202112'  , '시구' : '경기도' , '시군구' : '가평군' , '계약구분' : '일반용' , '사용량(kWh)' : sum}, ignore_index=True)

# %%
# a=[]
# for i in SIGUNGU:
#     a.append(i)
#
# print(a)

# %% [markdown]
# ### 4. 년월 체크!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

# %%
GyeonGiHap2 = df_3.copy()
GyeonGiHap2.reset_index(drop=True , inplace = True)
for i in range(len(SIGUNGU)):
    GyeonGiHap2 = GyeonGiHap2.append({'년월' :'201907-201912'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
GyeonGiHap2
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_15048\2665167033.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'201907-201912'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_15048\2665167033.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'201907-201912'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_15048\2665167033.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'201907-201912'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_15048\2665167033.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'201907-201912'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_15048\2665167033.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'201907-201912'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_15048\2665167033.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'201907-201912'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_15048\2665167033.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'201907-201912'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_15048\2665167033.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'201907-201912'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_15048\2665167033.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'201907-201912'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_15048\2665167033.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'201907-201912'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_15048\2665167033.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'201907-201912'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_15048\2665167033.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'201907-201912'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_15048\2665167033.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'201907-201912'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_15048\2665167033.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'201907-201912'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_15048\2665167033.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'201907-201912'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_15048\2665167033.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'201907-201912'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_15048\2665167033.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'201907-201912'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
# C:\Users\user\AppData\Local\Temp\ipykernel_15048\2665167033.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   GyeonGiHap2 = GyeonGiHap2.append({'년월' :'201907-201912'  , '시구' : '{}'.format(City) , '시군구' : '{}'.format(SIGUNGU[i]) , '계약구분' : '일반용' , '고객호수(호)' : sum3[i] ,  '사용량(kWh)' : sum2[i]} , ignore_index=True) #년월 파일마다 수정하기
#                 년월   시구  시군구 계약구분  고객호수(호)     사용량(kWh)
# 0           201907  강원도  강릉시  일반용  20,226   46,929,489
# 1           201908  강원도  강릉시  일반용  20,298   58,946,725
# 2           201909  강원도  강릉시  일반용  20,343   51,028,752
# 3           201910  강원도  강릉시  일반용  20,389   41,918,030
# 4           201911  강원도  강릉시  일반용  20,458   43,272,598
# ..             ...  ...  ...  ...      ...          ...
# 121  201907-201912  강원도  태백시  일반용     4139     45468139
# 122  201907-201912  강원도  평창군  일반용     6506    117635276
# 123  201907-201912  강원도  홍천군  일반용     8348    129366057
# 124  201907-201912  강원도  화천군  일반용     3387     56559723
# 125  201907-201912  강원도  횡성군  일반용     5125     60539075
#
# [126 rows x 6 columns]

# %% [markdown]
# ### 5. 날짜 체크!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

# %%
GyeonGiHap2 = GyeonGiHap2.loc[GyeonGiHap2['년월'] == '201907-201912']
GyeonGiHap2
# Out:
#                 년월   시구  시군구 계약구분 고객호수(호)   사용량(kWh)
# 108  201907-201912  강원도  강릉시  일반용   20378  291878537
# 109  201907-201912  강원도  고성군  일반용    4025   70496097
# 110  201907-201912  강원도  동해시  일반용    7249  107498841
# 111  201907-201912  강원도  삼척시  일반용    6747   83284423
# 112  201907-201912  강원도  속초시  일반용    8260  140963801
# 113  201907-201912  강원도  양구군  일반용    2793   42604689
# 114  201907-201912  강원도  양양군  일반용    4332   66590713
# 115  201907-201912  강원도  영월군  일반용    4166   42658552
# 116  201907-201912  강원도  원주시  일반용   25943  401705833
# 117  201907-201912  강원도  인제군  일반용    4682   72388759
# 118  201907-201912  강원도  정선군  일반용    5067  106421843
# 119  201907-201912  강원도  철원군  일반용    4875   75824689
# 120  201907-201912  강원도  춘천시  일반용   21142  405997669
# 121  201907-201912  강원도  태백시  일반용    4139   45468139
# 122  201907-201912  강원도  평창군  일반용    6506  117635276
# 123  201907-201912  강원도  홍천군  일반용    8348  129366057
# 124  201907-201912  강원도  화천군  일반용    3387   56559723
# 125  201907-201912  강원도  횡성군  일반용    5125   60539075

# %%
Final = pd.concat([GyeonGiHap2 , Hap])
Final = Final.sort_values('시군구')
Final
# Out:
#                 년월   시구  시군구 계약구분 고객호수(호)    사용량(kWh)
# 108  201907-201912  강원도  강릉시  일반용   20378   291878537
# 108  201907-201912  강원도  강릉시   합계   22869   954903155
# 109  201907-201912  강원도  고성군  일반용    4025    70496097
# 109  201907-201912  강원도  고성군   합계    4944   149328338
# 110  201907-201912  강원도  동해시  일반용    7249   107498841
# 110  201907-201912  강원도  동해시   합계    8279  1062932962
# 111  201907-201912  강원도  삼척시   합계    9430   763018709
# 111  201907-201912  강원도  삼척시  일반용    6747    83284423
# 112  201907-201912  강원도  속초시   합계    6826   256042300
# 112  201907-201912  강원도  속초시  일반용    8260   140963801
# 113  201907-201912  강원도  양구군  일반용    2793    42604689
# 113  201907-201912  강원도  양구군   합계    4057   101866633
# 114  201907-201912  강원도  양양군   합계    5282   144730213
# 114  201907-201912  강원도  양양군  일반용    4332    66590713
# 115  201907-201912  강원도  영월군  일반용    4166    42658552
# 115  201907-201912  강원도  영월군   합계    6955   554253839
# 116  201907-201912  강원도  원주시  일반용   25943   401705833
# 116  201907-201912  강원도  원주시   합계   27479  1194428316
# 117  201907-201912  강원도  인제군  일반용    4682    72388759
# 117  201907-201912  강원도  인제군   합계    6054   156316252
# 118  201907-201912  강원도  정선군   합계    6705   315259234
# 118  201907-201912  강원도  정선군  일반용    5067   106421843
# 119  201907-201912  강원도  철원군   합계    7401   230802952
# 119  201907-201912  강원도  철원군  일반용    4875    75824689
# 120  201907-201912  강원도  춘천시  일반용   21142   405997669
# 120  201907-201912  강원도  춘천시   합계   24648   867719802
# 121  201907-201912  강원도  태백시   합계    4666   146899149
# 121  201907-201912  강원도  태백시  일반용    4139    45468139
# 122  201907-201912  강원도  평창군   합계    9091   289933739
# 122  201907-201912  강원도  평창군  일반용    6506   117635276
# 123  201907-201912  강원도  홍천군   합계   12610   346803943
# 123  201907-201912  강원도  홍천군  일반용    8348   129366057
# 124  201907-201912  강원도  화천군   합계    4415   116968734
# 124  201907-201912  강원도  화천군  일반용    3387    56559723
# 125  201907-201912  강원도  횡성군  일반용    5125    60539075
# 125  201907-201912  강원도  횡성군   합계    9535   286581756

# %%
# Final['일반용 전기의 비율'] = (Final['사용량(kWh)'].loc[Final['계약구분'] == '일반용']) // (Final['사용량(kWh)'].loc[Final['계약구분'] == '합계'])
# Final
ex = (Final['사용량(kWh)'].loc[Final['계약구분'] == '일반용']).tolist()


ex
# Out:
# [291878537,
#  70496097,
#  107498841,
#  83284423,
#  140963801,
#  42604689,
#  66590713,
#  42658552,
#  401705833,
#  72388759,
#  106421843,
#  75824689,
#  405997669,
#  45468139,
#  117635276,
#  129366057,
#  56559723,
#  60539075]

# %%
ex_2 =(Final['사용량(kWh)'].loc[Final['계약구분'] == '합계']).tolist()
ex_2
# Out:
# [954903155,
#  149328338,
#  1062932962,
#  763018709,
#  256042300,
#  101866633,
#  144730213,
#  554253839,
#  1194428316,
#  156316252,
#  315259234,
#  230802952,
#  867719802,
#  146899149,
#  289933739,
#  346803943,
#  116968734,
#  286581756]

# %%
Rate = []
ilban = []
rae = 0
for i in range(len(ex)):
    rae = round(ex[i] / ex_2[i] *100 ,2)
    Rate.append(rae)
print(Rate)
# Out:
# [30.57, 47.21, 10.11, 10.92, 55.05, 41.82, 46.01, 7.7, 33.63, 46.31, 33.76, 32.85, 46.79, 30.95, 40.57, 37.3, 48.35, 21.12]

# %%
Rate3 = pd.Series(Rate)
Rate3

# Final = pd.concat([Final , Rate3])
# Final
# Out:
# 0    31
# 1    47
# 2    10
# 3    11
# 4    55
# 5    42
# 6    46
# 7     8
# 8    34
# 9    46
# 10   34
# 11   33
# 12   47
# 13   31
# 14   41
# 15   37
# 16   48
# 17   21
# dtype: float64

# %%
for j in range(len(Rate)):
    ilban.append('일반용')
#print(Rate)

Rate2 = pd.DataFrame()
Rate2['시군구'] = pd.DataFrame(SIGUNGU)
Rate2['계약구분'] = pd.DataFrame(ilban)
Rate2['비율'] = pd.DataFrame(Rate)
Rate2
#print(Rate2.dtypes)
# Out:
#     시군구 계약구분  비율
# 0   강릉시  일반용  31
# 1   고성군  일반용  47
# 2   동해시  일반용  10
# 3   삼척시  일반용  11
# 4   속초시  일반용  55
# 5   양구군  일반용  42
# 6   양양군  일반용  46
# 7   영월군  일반용   8
# 8   원주시  일반용  34
# 9   인제군  일반용  46
# 10  정선군  일반용  34
# 11  철원군  일반용  33
# 12  춘천시  일반용  47
# 13  태백시  일반용  31
# 14  평창군  일반용  41
# 15  홍천군  일반용  37
# 16  화천군  일반용  48
# 17  횡성군  일반용  21

# %%
Final = pd.merge(Final , Rate2, on=['시군구', '계약구분'] , how='left')

#Final.drop(['비율_y]' , axis = 1 , inplace = True)
#Final.rename(columns={'비율_y':'전체 계약종별 전력사용량 대비 일반용 사용량 비율'})
Final = Final.sort_values(['시군구' , '계약구분'])
Final
# Out:
#                년월   시구  시군구 계약구분 고객호수(호)    사용량(kWh)  비율
# 0   201907-201912  강원도  강릉시  일반용   20378   291878537  31
# 1   201907-201912  강원도  강릉시   합계   22869   954903155 NaN
# 2   201907-201912  강원도  고성군  일반용    4025    70496097  47
# 3   201907-201912  강원도  고성군   합계    4944   149328338 NaN
# 4   201907-201912  강원도  동해시  일반용    7249   107498841  10
# 5   201907-201912  강원도  동해시   합계    8279  1062932962 NaN
# 7   201907-201912  강원도  삼척시  일반용    6747    83284423  11
# 6   201907-201912  강원도  삼척시   합계    9430   763018709 NaN
# 9   201907-201912  강원도  속초시  일반용    8260   140963801  55
# 8   201907-201912  강원도  속초시   합계    6826   256042300 NaN
# 10  201907-201912  강원도  양구군  일반용    2793    42604689  42
# 11  201907-201912  강원도  양구군   합계    4057   101866633 NaN
# 13  201907-201912  강원도  양양군  일반용    4332    66590713  46
# 12  201907-201912  강원도  양양군   합계    5282   144730213 NaN
# 14  201907-201912  강원도  영월군  일반용    4166    42658552   8
# 15  201907-201912  강원도  영월군   합계    6955   554253839 NaN
# 16  201907-201912  강원도  원주시  일반용   25943   401705833  34
# 17  201907-201912  강원도  원주시   합계   27479  1194428316 NaN
# 18  201907-201912  강원도  인제군  일반용    4682    72388759  46
# 19  201907-201912  강원도  인제군   합계    6054   156316252 NaN
# 21  201907-201912  강원도  정선군  일반용    5067   106421843  34
# 20  201907-201912  강원도  정선군   합계    6705   315259234 NaN
# 23  201907-201912  강원도  철원군  일반용    4875    75824689  33
# 22  201907-201912  강원도  철원군   합계    7401   230802952 NaN
# 24  201907-201912  강원도  춘천시  일반용   21142   405997669  47
# 25  201907-201912  강원도  춘천시   합계   24648   867719802 NaN
# 27  201907-201912  강원도  태백시  일반용    4139    45468139  31
# 26  201907-201912  강원도  태백시   합계    4666   146899149 NaN
# 29  201907-201912  강원도  평창군  일반용    6506   117635276  41
# 28  201907-201912  강원도  평창군   합계    9091   289933739 NaN
# 31  201907-201912  강원도  홍천군  일반용    8348   129366057  37
# 30  201907-201912  강원도  홍천군   합계   12610   346803943 NaN
# 33  201907-201912  강원도  화천군  일반용    3387    56559723  48
# 32  201907-201912  강원도  화천군   합계    4415   116968734 NaN
# 34  201907-201912  강원도  횡성군  일반용    5125    60539075  21
# 35  201907-201912  강원도  횡성군   합계    9535   286581756 NaN

# %%
# Final['일반용 전기의 비율'] = Final.append(Rate)
# Final

# %% [markdown]
# ### 6. 날짜 체크!!!!!!!!!!!!!!!!!!!!1

# %%
Final.to_csv("{}_일반용_전력사용량_1907-12.csv".format(City) , mode = 'w' , encoding= 'cp949' , index =False) #파일명 수정

# %%
# Sigu = list(set(df_3['시군구'].tolist()))
#
# Sigu.sort()
#
# Sigu

# %%
# YearMonth = list(set(df_3['년월'].tolist()))
#
# YearMonth.sort()
# YearMonth

# %%
# Gayeak = list(set(df_3['계약구분'].tolist()))
#
# Gayeak.sort()
# Gayeak

# %%
# SEOUL = df_3.loc[(df_3['계약구분'] =='일반용')]
# SEOUL.drop(['고객호수(호)' ,'전기요금(원)' , '평균판매단가(원/kWh)'] , axis = 1 , inplace = True)
# #SEOUL.dtypes(['사용량(kWh)'])
# SEOUL

# %%
#SEOUL.to_csv("서울특별시_일반용_전력사용량.csv" , mode = 'w' , encoding= 'cp949')

# %%
# print(SEOUL.dtypes)
# SEOUL = SEOUL.astype({'사용량(kWh)' : 'float'})

# %%
# SEOUL

# %%
# a = SEOUL['사용량(kWh)'].tolist()
# int_list = map(int, a)
# b=0
# for i in int_list:
#     b+=i
#
# print(b)
